# %%
# Day 5 - Power BI Dashboard Development
# Bluestock MF Capstone Project

print("Day 5: Power BI Dashboard Complete!")
print("Pages created:")
print("1. Industry Overview")
print("2. Fund Performance") 
print("3. Investor Analytics")
print("4. SIP & Market Trends")
print("\nFile: dashboard/bluestock_mf_dashboard.pbix")
# Out:
# Day 5: Power BI Dashboard Complete!
# Pages created:
# 1. Industry Overview
# 2. Fund Performance
# 3. Investor Analytics
# 4. SIP & Market Trends
#
# File: dashboard/bluestock_mf_dashboard.pbix
